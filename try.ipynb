# %%
# Install required packages
# !pip install langgraph google-auth google-auth-oauthlib google-auth-httplib2 requests
# Out:
# Requirement already satisfied: langchain-openai in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (0.1.25)
# Requirement already satisfied: python-dotenv in c:\users\laveenbagai\appdata\roaming\python\python311\site-packages (1.1.1)
# Requirement already satisfied: langgraph in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (0.4.5)
# Collecting langchain-core<0.3.0,>=0.2.40 (from langchain-openai)
#   Using cached langchain_core-0.2.43-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from langchain-openai) (1.93.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.3.0,>=0.2.40->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.3.0,>=0.2.40->langchain-openai) (1.33)
# Collecting langsmith<0.2.0,>=0.1.112 (from langchain-core<0.3.0,>=0.2.40->langchain-openai)
#   Using cached langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Collecting packaging<25,>=23.2 (from langchain-core<0.3.0,>=0.2.40->langchain-openai)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\laveenbagai\appdata\roaming\python\python311\site-packages (from langchain-core<0.3.0,>=0.2.40->langchain-openai) (2.11.7)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain-core<0.3.0,>=0.2.40->langchain-openai)
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.3.0,>=0.2.40->langchain-openai) (4.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.40->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.40->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\laveenbagai\appdata\roaming\python\python311\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.40->langchain-openai) (3.11.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\laveenbagai\appdata\roaming\python\python311\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.40->langchain-openai) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.40->langchain-openai) (1.0.0)
# Requirement already satisfied: anyio in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.40->langchain-openai) (4.9.0)
# Requirement already satisfied: certifi in c:\users\laveenbagai\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.40->langchain-openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.40->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.40->langchain-openai) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.40->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.40->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\laveenbagai\appdata\roaming\python\python311\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.40->langchain-openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.40->langchain-openai) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.40->langchain-openai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.112->langchain-core<0.3.0,>=0.2.40->langchain-openai) (2.5.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\laveenbagai\appdata\roaming\python\python311\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2025.7.31)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.26 in c:\users\laveenbagai\appdata\roaming\python\python311\site-packages (from langgraph) (2.1.1)
# Requirement already satisfied: langgraph-prebuilt>=0.1.8 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from langgraph) (0.1.8)
# Requirement already satisfied: langgraph-sdk>=0.1.42 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from langgraph) (0.2.9)
# Requirement already satisfied: xxhash<4.0.0,>=3.5.0 in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\laveenbagai\appdata\roaming\python\python311\site-packages (from langgraph-checkpoint<3.0.0,>=2.0.26->langgraph) (1.10.0)
# Requirement already satisfied: colorama in c:\users\laveenbagai\appdata\local\programs\python\python311\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.40.0->langchain-openai) (0.4.6)
# Using cached langchain_core-0.2.43-py3-none-any.whl (397 kB)
# Using cached langsmith-0.1.147-py3-none-any.whl (311 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached tenacity-8.5.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, packaging, langsmith, langchain-core
#
#   Attempting uninstall: tenacity
#
#     Found existing installation: tenacity 9.1.2
#
#     Uninstalling tenacity-9.1.2:
#
#       Successfully uninstalled tenacity-9.1.2
#
#    ---------------------------------------- 0/4 [tenacity]
#    ---------------------------------------- 0/4 [tenacity]
#   Attempting uninstall: packaging
#    ---------------------------------------- 0/4 [tenacity]
#    ---------- ----------------------------- 1/4 [packaging]
#     Found existing installation: packaging 25.0
#    ---------- ----------------------------- 1/4 [packaging]
#     Uninstalling packaging-25.0:
#    ---------- ----------------------------- 1/4 [packaging]
#       Successfully uninstalled packaging-25.0
#    ---------- ----------------------------- 1/4 [packaging]
#    ---------- ----------------------------- 1/4 [packaging]
#    ---------- ----------------------------- 1/4 [packaging]
#    ---------- ----------------------------- 1/4 [packaging]
#    ---------- ----------------------------- 1/4 [packaging]
#   Attempting uninstall: langsmith
#    ---------- ----------------------------- 1/4 [packaging]
#     Found existing installation: langsmith 0.4.8
#    ---------- ----------------------------- 1/4 [packaging]
#     Uninstalling langsmith-0.4.8:
#    ---------- ----------------------------- 1/4 [packaging]
#       Successfully uninstalled langsmith-0.4.8
#    ---------- ----------------------------- 1/4 [packaging]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#    -------------------- ------------------- 2/4 [langsmith]
#   Attempting uninstall: langchain-core
#    -------------------- ------------------- 2/4 [langsmith]
#     Found existing installation: langchain-core 1.0.0
#    -------------------- ------------------- 2/4 [langsmith]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#     Uninstalling langchain-core-1.0.0:
#    ------------------------------ --------- 3/4 [langchain-core]
#       Successfully uninstalled langchain-core-1.0.0
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ------------------------------ --------- 3/4 [langchain-core]
#    ---------------------------------------- 4/4 [langchain-core]
#
# Successfully installed langchain-core-0.2.43 langsmith-0.1.147 packaging-24.2 tenacity-8.5.0
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\LaveenBagai\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\LaveenBagai\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pds-py (C:\Users\LaveenBagai\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\LaveenBagai\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pds-py (C:\Users\LaveenBagai\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#     WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\LaveenBagai\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\LaveenBagai\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pds-py (C:\Users\LaveenBagai\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 0.2.43 which is incompatible.
# langchain-text-splitters 0.3.9 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 0.2.43 which is incompatible.
# langchain-community 0.2.17 requires langchain<0.3.0,>=0.2.16, but you have langchain 0.3.27 which is incompatible.
# langchain-community 0.2.17 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.3.2 which is incompatible.
# marker-pdf 1.8.0 requires Pillow<11.0.0,>=10.1.0, but you have pillow 11.3.0 which is incompatible.
# marker-pdf 1.8.0 requires regex<2025.0.0,>=2024.4.28, but you have regex 2025.7.31 which is incompatible.
# paddlex 3.0.0 requires numpy==1.24.4; python_version < "3.12", but you have numpy 2.3.2 which is incompatible.
# paddlex 3.0.0 requires pandas<=1.5.3, but you have pandas 2.3.1 which is incompatible.
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\LaveenBagai\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python (C:\Users\LaveenBagai\AppData\Roaming\Python\Python311\site-packages)

# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
import time
import requests
from google.auth.transport.requests import Request
from google.oauth2 import service_account

# %%
def generate_content_with_text(prompt):
    """
    Sends a text prompt to the Gemini model and returns the response and response time.
    """
    start_time = time.time()

    try:
        # Get token from service account
        creds = service_account.Credentials.from_service_account_file(
            "prj-shared-connectivity-rg-001-db7c8a0de3aa.json",
            scopes=["https://www.googleapis.com/auth/cloud-platform"]
        )
        creds.refresh(Request())
        # API details - using the non-streaming endpoint for a complete response
        url = f"https://aiplatform-genai1.p.googleapis.com/v1/projects/prj-shared-connectivity-rg-001/locations/global/publishers/google/models/gemini-2.5-flash:generateContent"
        headers = {
            "Content-Type": "application/json",
            "Authorization": f"Bearer {creds.token}"
        }

        # Request payload (text only)
        data = {
            "contents": [{"role": "user", "parts": [{"text": prompt}]}],
            "generationConfig": {"temperature": 0.4, "topP": 1.0, "topK": 32, "maxOutputTokens": 4000}
        }

        # Make the request
        response = requests.post(url, headers=headers, json=data)
        response.raise_for_status()
        
        json_response = response.json()
        response_text = ""
        if "candidates" in json_response and json_response["candidates"]:
            candidate = json_response["candidates"][0]
            if "content" in candidate and "parts" in candidate["content"]:
                for part in candidate["content"]["parts"]:
                    if "text" in part:
                        response_text += part["text"]
        
        response_time = time.time() - start_time
        return {"response": response_text, "response_time": response_time}

    except Exception as e:
        response_time = time.time() - start_time
        error_message = f"An error occurred: {e}"
        if 'response' in locals() and hasattr(response, 'text'):
            error_message += f" | Response content: {response.text}"
        return {"error": error_message, "response_time": response_time}

# %%
# create a state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:
    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question: {question}'

    # ask that question to the Gemini model
    result = generate_content_with_text(prompt)
    
    # check if there was an error
    if "error" in result:
        state['answer'] = f"Error: {result['error']}"
    else:
        state['answer'] = result['response']

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'what is your name AI?'}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
# I do not have a name. I am a large language model, trained by Google.
